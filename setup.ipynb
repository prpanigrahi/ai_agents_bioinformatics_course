# %% [markdown]
# ## visual studio code
#
# You can use VS code or any other IDW. See that you are able to open .ipynb files. Also terminal support would be important.
#
# On windows, it is better to use ubuntu WSL

# %% [markdown]
# ## Python
#
# Prefereably Python 3.12.3

# %% [markdown]
# ## Install UV
#
# Go to https://docs.astral.sh/uv/getting-started/installation/#installation-methods
#
# Use either curl or pip based approach

# %% [markdown]
# ## Python packages needed
#
# ### Create a virtual env
#
# Remove ! while copy paste in terminal.

# %%
# Open terminal, go to any folder and run the following commands to create a virtual environment
! mkdir my_project
! cd my_project
! python -m venv .venv

# %% [markdown]
# ### Activate virtual env

# %%
# Activate the virtual env
! source .venv/bin/activate  

# On Windows use `.venv\Scripts\activate`

# %% [markdown]
# ### Install packages

# %%
! uv pip install openai-agents gradio python-dotenv openai requests bs4 
 
# For usecase of Clinvar release notes pdf extraction, install the following additional packages:

#### Tesseract OCR engine:On Ubuntu/Debian:
! sudo apt-get install tesseract-ocr

#Poppler (for pdf2image): On Ubuntu/Debian:
! sudo apt-get install poppler-utils

! uv pip install pytesseract pdf2image
# Out:
# Using Python 3.12.3 environment at: /mnt/c/Users/PriyabrataPanigrahi/Downloads/ai/prpanigrahi/agent-in-bioinfo/course/.venv
# Audited 6 packages in 911ms
# [sudo] password for priyabrata:
# sudo: a password is required
# ^C
# [sudo] password for priyabrata:

# %% [markdown]
# ### OpenAI key
#
# Go to OPENAI platform https://auth.openai.com/log-in
#
# Sign up
#
# Create api key . Copy this somewhere
#
# https://platform.openai.com/api-keys
#
#
# Create .env file in local directory and add your key as below
#
# OPENAI_API_KEY="mykey"

# %% [markdown]
# ## Install Ollama
#
# Go to https://github.com/ollama/ollama and install
#
# Pull below images
#
# ollama run gpt-oss
#
# ollama run llama3.2
#
# Open terminal in vscode and run below command to see the model list
#
# ollama ls
#
# To play with ollama model you can run
#
# ollama run llama3.2
